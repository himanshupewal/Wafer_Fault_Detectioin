# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing, metrics
import seaborn as sns
from sklearn.metrics import accuracy_score

# %%
path=r"C:/Users/himan/OneDrive/Desktop/Wafer_sensor_project/Notebook/Data/wafer_23012020_041211.csv"
df = pd.read_csv(path)
df
# Out:
#    Unnamed: 0  Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6  \
# 0   Wafer-801   2968.33   2476.58  2216.7333  1748.0885    1.1127     100.0
# 1   Wafer-802   2961.04   2506.43  2170.0666  1364.5157    1.5447     100.0
# 2   Wafer-803   3072.03   2500.68  2205.7445  1363.1048    1.0518     100.0
# 3   Wafer-804   3021.83   2419.83  2205.7445  1363.1048    1.0518     100.0
# 4   Wafer-805   3006.95   2435.34  2189.8111  1084.6502    1.1993     100.0
# ..        ...       ...       ...        ...        ...       ...       ...
# 95  Wafer-896   3013.66   2526.44  2185.2111  1141.6306    0.8447     100.0
# 96  Wafer-897   2982.87   2477.01  2315.2667  2360.1325    1.1259     100.0
# 97  Wafer-898   3084.82   2387.42  2171.5000  1028.4440    0.7899     100.0
# 98  Wafer-899   2955.87   2541.89        NaN        NaN       NaN       NaN
# 99  Wafer-900   2914.86   2465.11  2210.2778  2120.5760    1.0700     100.0
#
# ...

# %%
df.shape
# Out:
# (100, 592)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Sensor-1', 'Sensor-2', 'Sensor-3', 'Sensor-4',
#        'Sensor-5', 'Sensor-6', 'Sensor-7', 'Sensor-8', 'Sensor-9',
#        ...
#        'Sensor-582', 'Sensor-583', 'Sensor-584', 'Sensor-585', 'Sensor-586',
#        'Sensor-587', 'Sensor-588', 'Sensor-589', 'Sensor-590', 'Good/Bad'],
#       dtype='object', length=592)

# %%
df= df.drop(columns="Unnamed: 0",axis=1)

# %%
df.head()
# Out:
#    Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6  Sensor-7  \
# 0   2968.33   2476.58  2216.7333  1748.0885    1.1127     100.0   97.5822
# 1   2961.04   2506.43  2170.0666  1364.5157    1.5447     100.0   96.7700
# 2   3072.03   2500.68  2205.7445  1363.1048    1.0518     100.0  101.8644
# 3   3021.83   2419.83  2205.7445  1363.1048    1.0518     100.0  101.8644
# 4   3006.95   2435.34  2189.8111  1084.6502    1.1993     100.0  104.8856
#
#    Sensor-8  Sensor-9  Sensor-10  ...  Sensor-582  Sensor-583  Sensor-584  \
# 0    0.1242    1.5300    -0.0279  ...         NaN      0.5004      0.0120
# 1    0.1230    1.3953     0.0084  ...         NaN      0.4994      0.0115
# 2    0.1220    1.3896     0.0138  ...         NaN      0.4987      0.0118
# 3    0.1220    1.4108    -0.0046  ...         NaN      0.4934      0.0123
# 4    0.1234    1.5094    -0.0046  ...         NaN      0.4987      0.0145
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Columns: 591 entries, Sensor-1 to Good/Bad
# dtypes: float64(494), int64(97)
# memory usage: 461.8 KB

# %% [markdown]
# ----------494 columns has float values and 97 has int values.

# %%
df.describe()
# Out:
#           Sensor-1     Sensor-2     Sensor-3     Sensor-4   Sensor-5  \
# count    99.000000   100.000000    97.000000    97.000000  97.000000
# mean   3017.301212  2487.180300  2202.168281  1484.362181   1.180367
# std      71.819707    66.954212    30.350606   460.985871   0.349654
# min    2825.670000  2254.990000  2114.666700   978.783200   0.753100
# 25%    2973.040000  2446.595000  2189.966700  1111.543600   0.837300
# 50%    3004.390000  2493.890000  2200.988900  1244.289900   1.156900
# 75%    3070.385000  2527.525000  2213.211100  1963.801600   1.383000
# max    3221.210000  2664.520000  2315.266700  2363.641200   2.207300
#
#        Sensor-6    Sensor-7   Sensor-8    Sensor-9   Sensor-10  ...  \
# count      97.0   97.000000  97.000000  100.000000  100.000000  ...
# mean      100.0   97.449088   0.122195    1.461516    0.000243  ...
# std         0.0    5.553324   0.002006    0.071300    0.010610  ...
# min       100.0   83.423300   0.116000    1.317900   -0.027900  ...
# ...

# %%
df.isna().sum()
# Out:
# Sensor-1      1
# Sensor-2      0
# Sensor-3      3
# Sensor-4      3
# Sensor-5      3
#              ..
# Sensor-587    0
# Sensor-588    0
# Sensor-589    0
# Sensor-590    0
# Good/Bad      0
# Length: 591, dtype: int64

# %%
#df = df.dropna(axis=1)

# %%
df.shape
# Out:
# (100, 591)

# %% [markdown]
# before dropping -- we had 591 and after dropping we have 424

# %%
plt.figure(figsize=(15,100))

for i,c in enumerate(df.columns[1:45]):
    plt.subplot(60,3,i+1)
    plt.xlabel(c,weight="bold")

    sns.distplot(x=df[c])
    plt.tight_layout()

plt.show()
# Out:
# C:\Users\himan\AppData\Local\Temp\ipykernel_7176\2110322896.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[c])
# C:\Users\himan\AppData\Local\Temp\ipykernel_7176\2110322896.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[c])
# ...

# %%
plt.figure(figsize=(15,100))

for i,c in enumerate(df.columns[1:45]):
    plt.subplot(60,3,i+1)
    plt.xlabel(c,weight="bold")

    sns.boxenplot(x=df[c])
    plt.tight_layout()

plt.show()

# %% [markdown]
# Insight:
# Pretty good amount of them  are constant (have 0 standard deviation) or have left skewness and right skewness. It ain't possible to analyze each feature and deal with its outliers individually, thus we oughta depend upon the scaling.
#
# For the features with 0 standard deviation, we can straight away drop them and for others that do have outliers, we gotta go ahead with the Robust Scaling.

# %%
def get_cols(df:pd.DataFrame):

    col_to_drop = []

    num_cols = [i for i in df.columns if df[i].dtype!="O"]

    for col in num_cols:
        if df[col].std()==0:
            col_to_drop.append(col)
    return col_to_drop

# %%
def get_redundant_cols(df,missing_thresh =90):

    missing_ration = df.isna().sum().div(df.shape[0])
    col_to_drop =list(missing_ration[missing_ration > missing_thresh].index)
    return col_to_drop

# %%
redunt_cols = get_redundant_cols(df=df,missing_thresh=0.70)
redunt_cols
# Out:
# ['Sensor-158', 'Sensor-159', 'Sensor-293', 'Sensor-294']

# %%
col_drop =get_cols(df)
col_drop
# Out:
# ['Sensor-6',
#  'Sensor-14',
#  'Sensor-43',
#  'Sensor-50',
#  'Sensor-53',
#  'Sensor-70',
#  'Sensor-75',
#  'Sensor-98',
#  'Sensor-142',
#  'Sensor-150',
#  'Sensor-179',
#  'Sensor-180',
#  'Sensor-187',
#  'Sensor-190',
#  'Sensor-191',
#  'Sensor-192',
#  'Sensor-193',
#  'Sensor-194',
#  'Sensor-195',
#  'Sensor-207',
#  'Sensor-210',
#  'Sensor-227',
#  'Sensor-230',
#  'Sensor-231',
#  'Sensor-232',
#  'Sensor-233',
#  'Sensor-234',
#  'Sensor-235',
#  'Sensor-236',
#  'Sensor-237',
#  'Sensor-238',
#  'Sensor-241',
#  'Sensor-242',
#  'Sensor-243',
#  'Sensor-244',
#  'Sensor-257',
#  'Sensor-258',
#  'Sensor-259',
#  'Sensor-260',
#  'Sensor-261',
#  'Sensor-262',
#  'Sensor-263',
#  'Sensor-264',
#  'Sensor-265',
#  'Sensor-266',
#  'Sensor-267',
#  'Sensor-277',
#  'Sensor-285',
#  'Sensor-314',
#  'Sensor-315',
#  'Sensor-316',
#  'Sensor-323',
#  'Sensor-326',
#  'Sensor-327',
#  'Sensor-328',
#  'Sensor-329',
#  'Sensor-330',
#  'Sensor-331',
#  'Sensor-343',
# ...

# %%
cols_to_drop = col_drop+redunt_cols
cols_to_drop
# Out:
# ['Sensor-6',
#  'Sensor-14',
#  'Sensor-43',
#  'Sensor-50',
#  'Sensor-53',
#  'Sensor-70',
#  'Sensor-75',
#  'Sensor-98',
#  'Sensor-142',
#  'Sensor-150',
#  'Sensor-179',
#  'Sensor-180',
#  'Sensor-187',
#  'Sensor-190',
#  'Sensor-191',
#  'Sensor-192',
#  'Sensor-193',
#  'Sensor-194',
#  'Sensor-195',
#  'Sensor-207',
#  'Sensor-210',
#  'Sensor-227',
#  'Sensor-230',
#  'Sensor-231',
#  'Sensor-232',
#  'Sensor-233',
#  'Sensor-234',
#  'Sensor-235',
#  'Sensor-236',
#  'Sensor-237',
#  'Sensor-238',
#  'Sensor-241',
#  'Sensor-242',
#  'Sensor-243',
#  'Sensor-244',
#  'Sensor-257',
#  'Sensor-258',
#  'Sensor-259',
#  'Sensor-260',
#  'Sensor-261',
#  'Sensor-262',
#  'Sensor-263',
#  'Sensor-264',
#  'Sensor-265',
#  'Sensor-266',
#  'Sensor-267',
#  'Sensor-277',
#  'Sensor-285',
#  'Sensor-314',
#  'Sensor-315',
#  'Sensor-316',
#  'Sensor-323',
#  'Sensor-326',
#  'Sensor-327',
#  'Sensor-328',
#  'Sensor-329',
#  'Sensor-330',
#  'Sensor-331',
#  'Sensor-343',
# ...

# %%
## Feature Sapration

new_df = df.drop(cols_to_drop,axis=1)

# %%
new_df
# Out:
#     Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-7  Sensor-8  \
# 0    2968.33   2476.58  2216.7333  1748.0885    1.1127   97.5822    0.1242
# 1    2961.04   2506.43  2170.0666  1364.5157    1.5447   96.7700    0.1230
# 2    3072.03   2500.68  2205.7445  1363.1048    1.0518  101.8644    0.1220
# 3    3021.83   2419.83  2205.7445  1363.1048    1.0518  101.8644    0.1220
# 4    3006.95   2435.34  2189.8111  1084.6502    1.1993  104.8856    0.1234
# ..       ...       ...        ...        ...       ...       ...       ...
# 95   3013.66   2526.44  2185.2111  1141.6306    0.8447  100.5978    0.1217
# 96   2982.87   2477.01  2315.2667  2360.1325    1.1259   90.1144    0.1160
# 97   3084.82   2387.42  2171.5000  1028.4440    0.7899  101.5122    0.1224
# 98   2955.87   2541.89        NaN        NaN       NaN       NaN       NaN
# 99   2914.86   2465.11  2210.2778  2120.5760    1.0700   95.1089    0.1230
#
# ...
